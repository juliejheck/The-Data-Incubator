# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
# %matplotlib inline
sns.set
# Out:
# <function seaborn.rcmod.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)>

# %%
nyc_energy = pd.read_csv('C:\\Users\\Julie\\Downloads\\Electric_Consumption_And_Cost__2010_-_March_2019_.csv', low_memory=False)

# %%
nyc_energy.head()
# Out:
#   Development Name Borough Account Name Location Meter AMR   Meter Scope  \
# 0            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
# 1            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
# 2            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
# 3            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
# 4            ADAMS   BRONX        ADAMS   BLD 05      NONE  BLD 01 to 07
#
#    TDS #  EDP  RC Code Funding Source  ... Meter Number Estimated  \
# 0  118.0  248  B011800        FEDERAL  ...      7223256         N
# 1  118.0  248  B011800        FEDERAL  ...      7223256         N
# 2  118.0  248  B011800        FEDERAL  ...      7223256         N
# 3  118.0  248  B011800        FEDERAL  ...      7223256         N
# 4  118.0  248  B011800        FEDERAL  ...      7223256         N
#
#    Current Charges   Rate Class Bill Analyzed Consumption (KWH)  KWH Charges  \
# ...

# %%
nyc_load_data = nyc_energy[['Revenue Month', 'Current Charges', 'Consumption (KWH)', 'KWH Charges']]

print(nyc_load_data)
# Out:
#        Revenue Month  Current Charges  Consumption (KWH)  KWH Charges
# 0            2010-01         15396.82             128800      7387.97
# 1            2010-02         14556.34             115200      6607.87
# 2            2010-03         13904.98             103200      5919.55
# 3            2010-04         14764.04             105600      6057.22
# 4            2010-05         13729.54              97600      5598.34
# 5            2010-06         16689.19             124000      7112.64
# 6            2010-07         20563.52             156000      8948.16
# 7            2010-08         19675.94             151200      8672.83
# 8            2010-09         17716.94             119200      6837.31
# 9            2010-10         14742.21             103200      5919.55
# 10           2010-11         14237.01             108000      6194.88
# 11           2010-12         15347.78             116000      6653.76
# ...

# %%
nyc_energy.plot(x = "Revenue Month", y = ["Consumption (KWH)" ,"KWH Charges"], kind='line')
plt.xlabel("Year", fontsize=10)
plt.ylabel("Cost", fontsize=10)
# Out:
# Text(0, 0.5, 'Cost')
