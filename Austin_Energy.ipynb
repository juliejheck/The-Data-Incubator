# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
# %matplotlib inline
sns.set
# Out:
# <function seaborn.rcmod.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)>

# %%
austin_energy = pd.read_csv('C:\\Users\\Julie\\Downloads\\Electric_Consumption_And_Cost.csv', parse_dates = True)

# %%
austin_energy
# Out:
#            Date  Average kWh  Fuel Charge (Cents/kWh)  Average Bill
# 0    01/01/2000          820                    1.372         54.26
# 1    02/01/2000          766                    1.372         50.27
# 2    03/01/2000          707                    1.372         45.91
# 3    04/01/2000          715                    1.372         46.50
# 4    05/01/2000          838                    1.372         61.68
# 5    06/01/2000         1221                    1.372         96.88
# 6    07/01/2000         1442                    1.372        117.20
# 7    08/01/2000         1493                    1.635        125.81
# 8    09/01/2000         1368                    1.635        113.99
# 9    10/01/2000         1029                    1.635         81.94
# 10   11/01/2000          804                    2.211         59.83
# 11   12/01/2000          864                    2.211         64.77
# 12   01/01/2001         1019                    2.211         77.52
# ...

# %%
austin_energy.head()
# Out:
#          Date  Average kWh  Fuel Charge (Cents/kWh)  Average Bill
# 0  01/01/2000          820                    1.372         54.26
# 1  02/01/2000          766                    1.372         50.27
# 2  03/01/2000          707                    1.372         45.91
# 3  04/01/2000          715                    1.372         46.50
# 4  05/01/2000          838                    1.372         61.68

# %%
austin_load_data = austin_energy[['Date', 'Average Bill', 'Average kWh']]

print(austin_load_data)
# Out:
#            Date  Average Bill  Average kWh
# 0    01/01/2000         54.26          820
# 1    02/01/2000         50.27          766
# 2    03/01/2000         45.91          707
# 3    04/01/2000         46.50          715
# 4    05/01/2000         61.68          838
# 5    06/01/2000         96.88         1221
# 6    07/01/2000        117.20         1442
# 7    08/01/2000        125.81         1493
# 8    09/01/2000        113.99         1368
# 9    10/01/2000         81.94         1029
# 10   11/01/2000         59.83          804
# 11   12/01/2000         64.77          864
# 12   01/01/2001         77.52         1019
# 13   02/01/2001         68.05          855
# 14   03/01/2001         55.78          714
# 15   04/01/2001         56.91          727
# 16   05/01/2001         68.04          794
# 17   06/01/2001        104.16         1138
# 18   07/01/2001        123.28         1320
# 19   08/01/2001        146.28         1539
# 20   09/01/2001        124.75         1334
# ...

# %%
austin_energy.plot(x = "Date", y = ["Average Bill" ,"Average kWh"], kind='line')
plt.xlabel("Year", fontsize=10)
plt.ylabel("Cost", fontsize=10)
# Out:
# Text(0, 0.5, 'Cost')
